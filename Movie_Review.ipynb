# %%
from keras.datasets import imdb
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import cm
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.callbacks import EarlyStopping
from keras import models

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)

# %%
##training data shape review
print("Training data: ")
print(X.shape)
print(y.shape)
print("Classes: ")
print(np.unique(y))
# Out:
# Training data:
# (50000,)
# (50000,)
# Classes:
# [0 1]

# %%
print("Number of words: ")
print(len(np.unique(np.hstack(X))))
# Out:
# Number of words:
# 88585

# %%
print("Review length: ")
result = [len(x) for x in X]
print("Mean %.2f words (%f)" % (np.mean(result), np.std(result)))
# plot review length
plt.boxplot(result)
plt.show()
# Out:
# Review length:
# Mean 234.76 words (172.911495)

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=5000)

# %%
def vectorize_sequences(sequences, dimension=5000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results

# %%
# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)

# %%
# Our vectorized labels one-hot encoder
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(5000,)))
model.add(layers.Dense(32, activation='relu',))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
#Set validation set aside

x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
start_time_m1 = time.time()
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
total_time_m1 = time.time() - start_time_m1
# Out:
# Epoch 1/20
# 30/30 [==============================] - 11s 130ms/step - loss: 0.5484 - acc: 0.7561 - val_loss: 0.3758 - val_acc: 0.8563
# Epoch 2/20
# 30/30 [==============================] - 2s 53ms/step - loss: 0.2834 - acc: 0.8944 - val_loss: 0.2902 - val_acc: 0.8852
# Epoch 3/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.2000 - acc: 0.9265 - val_loss: 0.2931 - val_acc: 0.8821
# Epoch 4/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1624 - acc: 0.9431 - val_loss: 0.3177 - val_acc: 0.8763
# Epoch 5/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1338 - acc: 0.9526 - val_loss: 0.3403 - val_acc: 0.8720
# Epoch 6/20
# 30/30 [==============================] - 1s 29ms/step - loss: 0.1082 - acc: 0.9671 - val_loss: 0.3699 - val_acc: 0.8675
# Epoch 7/20
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0869 - acc: 0.9743 - val_loss: 0.4071 - val_acc: 0.8671
# Epoch 8/20
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0673 - acc: 0.9827 - val_loss: 0.4438 - val_acc: 0.8611
# Epoch 9/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0511 - acc: 0.9886 - val_loss: 0.4843 - val_acc: 0.8614
# Epoch 10/20
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0364 - acc: 0.9949 - val_loss: 0.5243 - val_acc: 0.8586
# Epoch 11/20
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0248 - acc: 0.9974 - val_loss: 0.5579 - val_acc: 0.8594
# Epoch 12/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0170 - acc: 0.9987 - val_loss: 0.5985 - val_acc: 0.8585
# Epoch 13/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0118 - acc: 0.9996 - val_loss: 0.6332 - val_acc: 0.8570
# Epoch 14/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0085 - acc: 0.9998 - val_loss: 0.6666 - val_acc: 0.8572
# Epoch 15/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0061 - acc: 0.9999 - val_loss: 0.6982 - val_acc: 0.8573
# Epoch 16/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0045 - acc: 0.9999 - val_loss: 0.7220 - val_acc: 0.8573
# Epoch 17/20
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.7467 - val_acc: 0.8573
# Epoch 18/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.7664 - val_acc: 0.8567
# Epoch 19/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.7878 - val_acc: 0.8565
# Epoch 20/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 0.8057 - val_acc: 0.8566

# %%
print("The Dense Convolutional Neural Network 1 layer took %.4f seconds to train." % (total_time_m1))
# Out:
# The Dense Convolutional Neural Network 1 layer took 41.4950 seconds to train.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                160032
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 161,121
# Trainable params: 161,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc
#predictions
pred = model.predict(x_test)
classes_x=np.argmax(pred,axis=1)

#accuracy
accuracy_score(y_test,classes_x)
# Out:
# 782/782 [==============================] - 5s 5ms/step
# 0.5

# %%
#Confusion Matrix
conf_mat = confusion_matrix(y_test, classes_x)
print(conf_mat)

conf_mat_normalized = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
sns.heatmap(conf_mat_normalized)
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# [[12500     0]
#  [12500     0]]
# Text(0.5, 23.52222222222222, 'Predicted label')

# %%
#Dense with Two Layer
model2 = models.Sequential()
model2.add(layers.Dense(32, activation='relu', input_shape=(5000,)))
model2.add(layers.Dense(32, activation='relu'))
model2.add(layers.Dense(32, activation='relu'))
model2.add(layers.Dense(1, activation='sigmoid'))

# %%
model2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
start_time_m2 = time.time()
history= model2.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
total_time_m2 = time.time() - start_time_m2

print("The Dense Convolutional Neural Network 2 layers took %.4f seconds to train." % (total_time_m2))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 8s 89ms/step - loss: 0.5088 - acc: 0.7919 - val_loss: 0.3264 - val_acc: 0.8686
# Epoch 2/20
# 30/30 [==============================] - 2s 58ms/step - loss: 0.2552 - acc: 0.9037 - val_loss: 0.2948 - val_acc: 0.8830
# Epoch 3/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1877 - acc: 0.9291 - val_loss: 0.3012 - val_acc: 0.8820
# Epoch 4/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1506 - acc: 0.9465 - val_loss: 0.3366 - val_acc: 0.8759
# Epoch 5/20
# 30/30 [==============================] - 1s 31ms/step - loss: 0.1257 - acc: 0.9552 - val_loss: 0.3728 - val_acc: 0.8722
# Epoch 6/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1031 - acc: 0.9657 - val_loss: 0.4202 - val_acc: 0.8670
# Epoch 7/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0829 - acc: 0.9721 - val_loss: 0.4784 - val_acc: 0.8615
# Epoch 8/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0634 - acc: 0.9803 - val_loss: 0.5702 - val_acc: 0.8578
# Epoch 9/20
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0500 - acc: 0.9859 - val_loss: 0.6292 - val_acc: 0.8510
# Epoch 10/20
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0384 - acc: 0.9899 - val_loss: 0.6931 - val_acc: 0.8561
# Epoch 11/20
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0337 - acc: 0.9913 - val_loss: 0.7606 - val_acc: 0.8517
# Epoch 12/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0214 - acc: 0.9956 - val_loss: 0.8232 - val_acc: 0.8529
# Epoch 13/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0127 - acc: 0.9983 - val_loss: 0.8869 - val_acc: 0.8502
# Epoch 14/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0077 - acc: 0.9996 - val_loss: 0.9477 - val_acc: 0.8499
# Epoch 15/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0046 - acc: 0.9998 - val_loss: 1.0029 - val_acc: 0.8497
# Epoch 16/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0029 - acc: 0.9999 - val_loss: 1.0643 - val_acc: 0.8500
# Epoch 17/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0019 - acc: 0.9999 - val_loss: 1.1148 - val_acc: 0.8504
# Epoch 18/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.1632 - val_acc: 0.8489
# Epoch 19/20
# 30/30 [==============================] - 1s 30ms/step - loss: 9.9934e-04 - acc: 1.0000 - val_loss: 1.2119 - val_acc: 0.8501
# Epoch 20/20
# 30/30 [==============================] - 1s 26ms/step - loss: 7.7532e-04 - acc: 1.0000 - val_loss: 1.2537 - val_acc: 0.8501
# The Dense Convolutional Neural Network 2 layers took 33.2516 seconds to train.

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('DNN 2 layer Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('DNN 2 layer Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 32)                160032
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 162,177
# Trainable params: 162,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
from numpy.ma.core import argmax
pred = model2.predict(x_test)
classes_x=argmax(pred,axis=-1)
#accuracy
accuracy_score(y_test,classes_x)
# Out:
# 782/782 [==============================] - 3s 4ms/step
# 0.5
